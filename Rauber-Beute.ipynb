# %%
from iteration import *

a = 0.05; b = 0.002; c = 0.06; d = 0.001



plot_iteration(rauber_beute, x0=[100, 30], n=300, a=a, b=b, c=c, d=d)

# %%
# Fixpunkte für Rauber Beute

from sympy import *

(x, y) = symbols('x y')


system = [
    x + a*x - b*x*y - x,
    y - c*y + d*y*x - y
]

solve(system, [x,y])
# Out:
# [(0.0, 0.0), (60.0000000000000, 25.0000000000000)]

# %%
print(c/d, a/b)
# Out:
# 60.0 25.0

# %%
x_list = iteration(rauber_beute, x=[150, 30], n=300, a=a, b=b, c=c, d=d)
#print(x_list)

al = list([])
bl = list([])

for point in x_list:
    al.append(point[0])
    bl.append(point[1])


plt.plot(al, bl)
